# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.nn.parameter import Parameter
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, utils, datasets
import matplotlib.pyplot as plt


torch.set_printoptions(linewidth=120)
torch.set_grad_enabled(True)

# %% [markdown]
# ## Network

# %%
class Network(nn.Module):
    def __init__(self):
        super().__init__()

        self.features = nn.Sequential(
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(3, 32, kernel_size=5, stride=2),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.1),

            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(32, 64, kernel_size=5, stride=2),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.2),

            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(64, 128, kernel_size=5),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.2),

            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(128,256, kernel_size=3),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
        )

        self.classifier = nn.Sequential(
            nn.Dropout(p = 0.2),
            nn.Linear(16384, 256),
            # nn.BatchNorm1d(256),
            nn.ReLU(inplace=True),

            nn.Dropout(p = 0.2),
            nn.Linear(256, 128),
            # nn.BatchNorm1d(128),
            nn.ReLU(inplace=True),

            nn.Dropout(p = 0.1),
            nn.Linear(128, 6),
#             nn.BatchNorm1d(512), not in this model
            nn.Softmax(dim=1)
        )



    def forward(self, x):
        x = self.features(x)
        x = x.reshape(-1, 16384)
        x = self.classifier(x)

        return x

def get_num_correct(pred, label):
    return pred.argmax(dim=1).eq(label).sum().item()

# %% [markdown]
# ## Moving To GPU

# %%
device = torch.device("cuda:0")
print(device)
if torch.cuda.is_available():
    device = torch.device("cuda:0")  # you can continue going on here, like cuda:1 cuda:2....etc.
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")
# Out:
# cuda:0
# Running on the GPU

# %% [markdown]
# # **Test the Model**

# %% [markdown]
# ## Test Dataset Creation

# %%
mean = 0.2069
std = 0.1471

# %%
test_data_dir = '/content/drive/My Drive/al5083/al5083/test'

transform_test = transforms.Compose([
     transforms.CenterCrop((800,800)),
     transforms.ToTensor(),
     ])

test_dataset = datasets.ImageFolder(root =test_data_dir,transform = transform_test)
test_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 6386
#     Root location: /content/drive/My Drive/al5083/al5083/test
#     StandardTransform
# Transform: Compose(
#                CenterCrop(size=(800, 800))
#                ToTensor()
#            )

# %% [markdown]
# ## Generating true labels

# %%
import json
# Opening JSON file
f = open('/content/drive/My Drive/al5083/al5083/test/test.json',)

label_test = json.load(f)

# %%
keys_orig = list(label_test.keys())
values = list(label_test.values())
keys = []
for key in keys_orig:
  a_string = key
  a_string = a_string.replace("/", " ")
  x = a_string.split()
  string = x[0]+' '+x[1]
  keys.append(string)
true_test_labels_dict = {keys[i]: values[i] for i in range(len(keys))}
true_test_labels_dict
# Out:
# {'170906-143512-Al 2mm-part2': 1,
#  '170904-155610-Al 2mm': 2,
#  '170906-143512-Al 2mm-part1': 2,
#  '170904-154202-Al 2mm-part1': 2,
#  '170904-150144-Al 2mm-part2': 4,
#  '170906-155007-Al 2mm-part2': 4,
#  '170913-154448-Al 2mm': 0,
#  '170906-113317-Al 2mm-part1': 0,
#  '170905-112213-Al 2mm': 0,
#  '170906-104925-Al 2mm': 0,
#  '170904-152301-Al 2mm-part2': 5,
#  '170906-153326-Al 2mm-part3': 3,
#  '170906-151724-Al 2mm-part1': 3,
#  '170906-155007-Al 2mm-part1': 3}

# %% [markdown]
# ### 2 Class Test

# %%
true_test_labels_dict2 = {}
for key,value in true_test_labels_dict.items():
  if value ==0:
    val = 0
  else:
    val = 1
  dict2 = {key:val}
  true_test_labels_dict2.update(dict2)
true_test_labels_dict2
# Out:
# {'170906-143512-Al 2mm-part2': 1,
#  '170904-155610-Al 2mm': 1,
#  '170906-143512-Al 2mm-part1': 1,
#  '170904-154202-Al 2mm-part1': 1,
#  '170904-150144-Al 2mm-part2': 1,
#  '170906-155007-Al 2mm-part2': 1,
#  '170913-154448-Al 2mm': 0,
#  '170906-113317-Al 2mm-part1': 0,
#  '170905-112213-Al 2mm': 0,
#  '170906-104925-Al 2mm': 0,
#  '170904-152301-Al 2mm-part2': 1,
#  '170906-153326-Al 2mm-part3': 1,
#  '170906-151724-Al 2mm-part1': 1,
#  '170906-155007-Al 2mm-part1': 1}

# %% [markdown]
# ## Matching the loaded data with Labels

# %%
original_test_labels_dict = test_dataset.class_to_idx
original_test_labels_dict
# Out:
# {'170904-150144-Al 2mm-part2': 0,
#  '170904-152301-Al 2mm-part2': 1,
#  '170904-154202-Al 2mm-part1': 2,
#  '170904-155610-Al 2mm': 3,
#  '170905-112213-Al 2mm': 4,
#  '170906-104925-Al 2mm': 5,
#  '170906-113317-Al 2mm-part1': 6,
#  '170906-143512-Al 2mm-part1': 7,
#  '170906-143512-Al 2mm-part2': 8,
#  '170906-151724-Al 2mm-part1': 9,
#  '170906-153326-Al 2mm-part3': 10,
#  '170906-155007-Al 2mm-part1': 11,
#  '170906-155007-Al 2mm-part2': 12,
#  '170913-154448-Al 2mm': 13}

# %% [markdown]
# ### 2 Class test

# %%
original_test_labels_dict2 = {}
for key,value in original_test_labels_dict.items():
  if value ==0:
    val = 0
  else:
    val = 1
  dict2 = {key:val}
  original_test_labels_dict2.update(dict2)
original_test_labels_dict2
# Out:
# {'170904-150144-Al 2mm-part2': 0,
#  '170904-152301-Al 2mm-part2': 1,
#  '170904-154202-Al 2mm-part1': 1,
#  '170904-155610-Al 2mm': 1,
#  '170905-112213-Al 2mm': 1,
#  '170906-104925-Al 2mm': 1,
#  '170906-113317-Al 2mm-part1': 1,
#  '170906-143512-Al 2mm-part1': 1,
#  '170906-143512-Al 2mm-part2': 1,
#  '170906-151724-Al 2mm-part1': 1,
#  '170906-153326-Al 2mm-part3': 1,
#  '170906-155007-Al 2mm-part1': 1,
#  '170906-155007-Al 2mm-part2': 1,
#  '170913-154448-Al 2mm': 1}

# %% [markdown]
# ## Label Mapping

# %%
test_label_map_dict = {}

for key,value in original_test_labels_dict.items():
  test_label_map_dict.update({value:true_test_labels_dict[key]})
test_label_map_dict
# Out:
# {0: 4,
#  1: 5,
#  2: 2,
#  3: 2,
#  4: 0,
#  5: 0,
#  6: 0,
#  7: 2,
#  8: 1,
#  9: 3,
#  10: 3,
#  11: 3,
#  12: 4,
#  13: 0}

# %% [markdown]
# ### 2 Class test

# %%
test_label_map_dict2 = {}

for key,value in original_test_labels_dict.items():
  test_label_map_dict2.update({value:true_test_labels_dict2[key]})
test_label_map_dict2
# Out:
# {0: 1,
#  1: 1,
#  2: 1,
#  3: 1,
#  4: 0,
#  5: 0,
#  6: 0,
#  7: 1,
#  8: 1,
#  9: 1,
#  10: 1,
#  11: 1,
#  12: 1,
#  13: 0}

# %% [markdown]
# ## Loading The Model

# %%
PATH_model = "/content/drive/My Drive/model_classical_train_bin.pt"

# %%
import torch
net = Network()
pretrained_dict = torch.load(PATH_model, map_location=device)
model_dict = net.state_dict()

# Filter out layers with mismatched shapes
pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in model_dict and v.size() == model_dict[k].size()}

# Update the current model's state dictionary
model_dict.update(pretrained_dict)
net.load_state_dict(model_dict)
net.to(device)
# Out:
# Network(
#   (features): Sequential(
#     (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (1): Conv2d(3, 32, kernel_size=(5, 5), stride=(2, 2))
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Dropout(p=0.1, inplace=False)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(32, 64, kernel_size=(5, 5), stride=(2, 2))
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): Dropout(p=0.2, inplace=False)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1))
#     (12): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): Dropout(p=0.2, inplace=False)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU(inplace=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=16384, out_features=256, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Dropout(p=0.1, inplace=False)
#     (7): Linear(in_features=128, out_features=6, bias=True)
#     (8): Softmax(dim=1)
#   )
# )

# %%
torch.cuda.empty_cache()
torch.set_grad_enabled(False)

# %% [markdown]
# ## Testing

# %% [markdown]
# ### 2 Class Test

# %%
test_loader1 = DataLoader(test_dataset, batch_size=10,shuffle=True)

# %%
def get_num_correct2(pred,true):
  prediction = pred.argmax(dim=1)
  label = []
  for val in prediction:
    if val.item() ==0:
      label.append(0)
    else:
      label.append(1)

  n = len(true)
  correct = 0
  for x in range(n):
      if true[x] == label[x]:
          correct += 1
  return correct

# %%
total_correct=0
correct_predictions = []
i=0
total = 0
for batch in test_loader1:
  image, label_original = batch
  label = [test_label_map_dict2[lab.item()] for lab in label_original]
  label = torch.tensor(label)


  pred = net(image.to(device))

  total_correct += get_num_correct2(pred,label.to(device))
  correct_predictions.append(total_correct)

  total += len(label)
  acc = 100*total_correct/(total)
  print('Batch No: ',i+1,'/',len(test_loader1),', Accuracy till Now : ', acc)
  i=i+1
print(total_correct/len(test_dataset))
# Out:
# Batch No:  1 / 639 , Accuracy till Now :  70.0
# Batch No:  2 / 639 , Accuracy till Now :  70.0
# Batch No:  3 / 639 , Accuracy till Now :  66.66666666666667
# Batch No:  4 / 639 , Accuracy till Now :  67.5
# Batch No:  5 / 639 , Accuracy till Now :  72.0
# Batch No:  6 / 639 , Accuracy till Now :  65.0
# Batch No:  7 / 639 , Accuracy till Now :  61.42857142857143
# Batch No:  8 / 639 , Accuracy till Now :  63.75
# Batch No:  9 / 639 , Accuracy till Now :  58.888888888888886
# Batch No:  10 / 639 , Accuracy till Now :  62.0
# Batch No:  11 / 639 , Accuracy till Now :  62.72727272727273
# Batch No:  12 / 639 , Accuracy till Now :  63.333333333333336
# Batch No:  13 / 639 , Accuracy till Now :  62.30769230769231
# Batch No:  14 / 639 , Accuracy till Now :  63.57142857142857
# Batch No:  15 / 639 , Accuracy till Now :  64.0
# Batch No:  16 / 639 , Accuracy till Now :  63.75
# Batch No:  17 / 639 , Accuracy till Now :  62.35294117647059
# Batch No:  18 / 639 , Accuracy till Now :  62.22222222222222
# Batch No:  19 / 639 , Accuracy till Now :  62.63157894736842
# Batch No:  20 / 639 , Accuracy till Now :  61.5
# Batch No:  21 / 639 , Accuracy till Now :  62.857142857142854
# Batch No:  22 / 639 , Accuracy till Now :  63.63636363636363
# Batch No:  23 / 639 , Accuracy till Now :  63.47826086956522
# Batch No:  24 / 639 , Accuracy till Now :  63.75
# Batch No:  25 / 639 , Accuracy till Now :  62.8
# Batch No:  26 / 639 , Accuracy till Now :  62.69230769230769
# Batch No:  27 / 639 , Accuracy till Now :  63.333333333333336
# Batch No:  28 / 639 , Accuracy till Now :  63.214285714285715
# Batch No:  29 / 639 , Accuracy till Now :  63.10344827586207
# Batch No:  30 / 639 , Accuracy till Now :  63.333333333333336
# Batch No:  31 / 639 , Accuracy till Now :  63.87096774193548
# Batch No:  32 / 639 , Accuracy till Now :  63.75
# Batch No:  33 / 639 , Accuracy till Now :  63.93939393939394
# Batch No:  34 / 639 , Accuracy till Now :  64.70588235294117
# Batch No:  35 / 639 , Accuracy till Now :  64.85714285714286
# Batch No:  36 / 639 , Accuracy till Now :  65.0
# Batch No:  37 / 639 , Accuracy till Now :  65.4054054054054
# Batch No:  38 / 639 , Accuracy till Now :  65.78947368421052
# Batch No:  39 / 639 , Accuracy till Now :  66.66666666666667
# Batch No:  40 / 639 , Accuracy till Now :  67.0
# Batch No:  41 / 639 , Accuracy till Now :  66.82926829268293
# Batch No:  42 / 639 , Accuracy till Now :  66.19047619047619
# Batch No:  43 / 639 , Accuracy till Now :  66.04651162790698
# Batch No:  44 / 639 , Accuracy till Now :  65.9090909090909
# Batch No:  45 / 639 , Accuracy till Now :  66.66666666666667
# Batch No:  46 / 639 , Accuracy till Now :  67.3913043478261
# Batch No:  47 / 639 , Accuracy till Now :  67.23404255319149
# Batch No:  48 / 639 , Accuracy till Now :  67.29166666666667
# Batch No:  49 / 639 , Accuracy till Now :  67.14285714285714
# Batch No:  50 / 639 , Accuracy till Now :  67.2
# Batch No:  51 / 639 , Accuracy till Now :  67.05882352941177
# Batch No:  52 / 639 , Accuracy till Now :  66.34615384615384
# Batch No:  53 / 639 , Accuracy till Now :  66.0377358490566
# Batch No:  54 / 639 , Accuracy till Now :  65.74074074074075
# Batch No:  55 / 639 , Accuracy till Now :  65.27272727272727
# Batch No:  56 / 639 , Accuracy till Now :  65.35714285714286
# Batch No:  57 / 639 , Accuracy till Now :  65.43859649122807
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-1ec41492d764> in <cell line: 5>()
#       3 i=0
#       4 total = 0
# ----> 5 for batch in test_loader1:
#       6   image, label_original = batch
#       7   label = [test_label_map_dict2[lab.item()] for lab in label_original]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     243         """
#     244         path, target = self.samples[index]
# --> 245         sample = self.loader(path)
#     246         if self.transform is not None:
#     247             sample = self.transform(sample)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in default_loader(path)
#     282         return accimage_loader(path)
#     283     else:
# --> 284         return pil_loader(path)
#     285
#     286
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in pil_loader(path)
#     261     # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
#     262     with open(path, "rb") as f:
# --> 263         img = Image.open(f)
#     264         return img.convert("RGB")
#     265
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3234         exclusive_fp = True
#    3235
# -> 3236     prefix = fp.read(16)
#    3237
#    3238     preinit()
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2 Class Test

# %%
# test_loader1 = DataLoader(test_dataset, batch_size=30,shuffle=True)

# %%
def get_num_correct2(pred,true):
  prediction = pred.argmax(dim=1)
  label = []
  for val in prediction:
    if val.item() ==0:
      label.append(0)
    else:
      label.append(1)

  n = len(true)
  correct = 0
  for x in range(n):
      if true[x] == label[x]:
          correct += 1
  return correct

# %%
total_correct=0
condition = True
for batch in test_loader1:
  if condition:
    image, label_original = batch
    label = [test_label_map_dict2[lab.item()] for lab in label_original]
    label = torch.tensor(label)


    pred = net(image.to(device))

    total_correct += get_num_correct2(pred,label.to(device))

    condition = False
  else:
    break
label_2class = label
pred_2class = pred.argmax(dim=1)

# %% [markdown]
# ## Defect Correspoing the label

# %%
weld_type = {
    0: 'Good Weld',
    1: 'Defective Weld',
    2: 'Defective Weld',
    3: 'Defective Weld',
    4:'Defective Weld',
    5:'Defective Weld'
}

# %%
#defect_label = {
    #0: 'Good Weld',
    #1: ' Burn through',
    #2: 'Contamination',
    #3: 'Lack of fusion',
    #4:'Misalignment',
    #5:'Lack of penetration'
#}

# %% [markdown]
# ### 2 Class

# %%
defect_label2 = {
    0: 'Good Weld',
    1: 'Defective Weld'
}

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 2 Class

# %%
for i in range(len(pred_2class)):
  print('=> Image No :',i+1)
  img= image[i]
  print(' Type of Weld :', weld_type[label_2class[i].item()])
  print(' Actual Defect :', defect_label2[label_2class[i].item()])
  print(' Predicted Defect : ',defect_label2[pred_2class[i].item()])
  plt.imshow(  img.permute(1, 2, 0)  )
  plt.show()
  print('-------------------xxxx--------------------------')
# Out:
# => Image No : 1
#  Type of Weld : Defective Weld
#  Actual Defect : Defective Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
# => Image No : 2
#  Type of Weld : Good Weld
#  Actual Defect : Good Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
# => Image No : 3
#  Type of Weld : Defective Weld
#  Actual Defect : Defective Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
# => Image No : 4
#  Type of Weld : Good Weld
#  Actual Defect : Good Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
# => Image No : 5
#  Type of Weld : Defective Weld
#  Actual Defect : Defective Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
# => Image No : 6
#  Type of Weld : Defective Weld
#  Actual Defect : Defective Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
# => Image No : 7
#  Type of Weld : Good Weld
#  Actual Defect : Good Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
# => Image No : 8
#  Type of Weld : Good Weld
#  Actual Defect : Good Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
# => Image No : 9
#  Type of Weld : Good Weld
#  Actual Defect : Good Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
# => Image No : 10
#  Type of Weld : Defective Weld
#  Actual Defect : Defective Weld
#  Predicted Defect :  Defective Weld
# -------------------xxxx--------------------------
